# %%
import pandas as pd
import numpy as np

# %%
# Before you doing this, you need to remove the first line(header) of the below file
match_best = pd.read_csv('Algorithm/match_best.csv', header=None)
match_second = pd.read_csv('Algorithm/match_second.csv', header=None)
match_third = pd.read_csv('Algorithm/match_third.csv', header=None)
raw_data = pd.read_csv('Algorithm/raw_data.csv', header=None)
Training_data = pd.read_csv('Algorithm/training_data.csv', header=None)
Testing_data = pd.read_csv('Algorithm/testing_data.csv', header=None)

# %%
def S(x) :
    if x > -1 and x < 1:
        return x
    elif x >= 1 :
        return 1
    else :
        return -1

# %%
X = Training_data.ix[0:, 0:113]
Y = Training_data.ix[0:, 114]
X_Mul_Y = X.mul(Y, axis=0)
Sum_X_Mul_Y = X_Mul_Y.sum()
X_T = X.transpose()
X_T_Dot_X = X_T.dot(X)
Parameter = X_T_Dot_X.as_matrix()

# %%
def Optimization(parameter_l, parameter_u, parameter_g) :
    
    U = match_second - match_third
    data = np.identity(115)
    
    I = pd.DataFrame(data=data[1:,1:])
    C = pd.concat([parameter_l * I, parameter_u * U],ignore_index=True)
    
    # initial w 
    random_num = np.random.uniform(-1, 1, size=114)
    w = pd.DataFrame(data=random_num)
    
    C_Dot_W = C.dot(w) / parameter_g
    
    A = C_Dot_W[0].apply(S)
    # C_T : C 's transpose
    C_T = C.transpose()
    C_T_Dot_A = 0.5 * C_T.dot(A)
    
    Target = Sum_X_Mul_Y - C_T_Dot_A
    Target = Target.as_matrix()
    
    w = np.linalg.solve(Parameter, Target)
    
    iterations = 0
    delta_A = 1000
    delta_w = 1000
    bound = 0.001

    while delta_A > bound and delta_w > bound :
        iterations += 1
        if iterations > 20 :
            return None
        
        C_Dot_W = C.dot(w) / parameter_g

        # update vector A
        A_now = C_Dot_W.apply(S)

        C_T_Dot_A = 0.5 * C_T.dot(A_now)
        Target = Sum_X_Mul_Y - C_T_Dot_A
        Target = Target.as_matrix()

        # update vector w
        w_now = np.linalg.solve(Parameter, Target)

        delta_A = np.linalg.norm(A_now-A)
        delta_w = np.linalg.norm(w_now-w)

        A = A_now
        w = w_now

        print 'iterations:' + str(iterations) + ' ' + \
                'delta_A:' + str(delta_A) + ' ' + \
                'delta_w:' + str(delta_w)  
    
    return w

# %%
test_features = Testing_data.ix[0:, 0:113]
test_flag = Testing_data.ix[0:, 114]

# %%
def Evaluation(w) :
    
    result = np.dot(test_features, w)
    predict_flag = result > 0
    
    true_positive = 0.0
    true_negative = 0.0
    false_positive = 0.0
    false_negative = 0.0

    for i in range( len(predict_flag) ):
        if predict_flag[i] == True and test_flag[i] == 1 :
            true_positive += 1
        if predict_flag[i] == False and test_flag[i] == -1 :
            true_negative += 1
        if predict_flag[i] == True and test_flag[i] == -1 :
            false_positive += 1
        if predict_flag[i] == False and test_flag[i] == 1 :
            false_negative += 1
            
    ACC = (true_positive + true_negative) / (true_positive + true_negative + false_positive + false_negative)
    PRE = true_positive / (true_positive + false_positive)
    REC = true_positive / (true_positive + false_negative)
    F1 = 2*( PRE * REC) / (PRE + REC)
    
    return F1 # ACC , PRE, REC

# %%
w = Optimization(0.01,1.32,0.04)
print w
# Out:
# iterations:1 delta_A:93.1583258365 delta_w:0.653980570722
# iterations:2 delta_A:55.8892957449 delta_w:0.334665003173
# iterations:3 delta_A:45.2278244728 delta_w:0.257825632911
# iterations:4 delta_A:37.9919793086 delta_w:0.206555865869
# iterations:5 delta_A:32.7601792632 delta_w:0.171089749494
# iterations:6 delta_A:28.2753028428 delta_w:0.138889586542
# iterations:7 delta_A:24.5189255169 delta_w:0.119230470717
# iterations:8 delta_A:21.6259560777 delta_w:0.102563914057
# iterations:9 delta_A:19.2953129194 delta_w:0.0916813792206
# iterations:10 delta_A:17.2981213447 delta_w:0.082023521874
# iterations:11 delta_A:15.7480755042 delta_w:0.0742851195956
# iterations:12 delta_A:14.2714691342 delta_w:0.0671074539653
# iterations:13 delta_A:13.0788327149 delta_w:0.0613225170229
# iterations:14 delta_A:11.9893038407 delta_w:0.0561246666042
# iterations:15 delta_A:11.0206403141 delta_w:0.0516333577163
# iterations:16 delta_A:10.1622290143 delta_w:0.0475225004598
# iterations:17 delta_A:9.35135305635 delta_w:0.0438049741049
# iterations:18 delta_A:8.63268475145 delta_w:0.0403406039792
# iterations:19 delta_A:7.95980150223 delta_w:0.0371988230678
# iterations:20 delta_A:7.3645375111 delta_w:0.0343412514395
# None

# %%
# just for testing 
parameter_l = 0.01 
parameter_u = 0.0
parameter_g = 0.0
Performace = {}
loops = 0

while parameter_l < 100.0:

    if parameter_l < 0.1 :
        parameter_l += 0.03
    elif parameter_l >= 0.1 and parameter_l < 1.0:
        parameter_l += 0.3
    elif parameter_l >= 1.0 and parameter_l < 10.0:
        parameter_l += 3.0
    else :
        parameter_l += 30.0
    
    parameter_u = 0.0
    parameter_g = 0.0 

    while parameter_u < 100.0:

        if parameter_u < 0.1 :
            parameter_u += 0.03
        elif parameter_u >= 0.1 and parameter_u < 1.0:
            parameter_u += 0.3
        elif parameter_u >= 1.0 and parameter_u < 10.0:
            parameter_u += 3.0
        else :
            parameter_u += 30.0

        parameter_g = 0.0 

        while parameter_g < 100.0 :
            loops += 1
            print loops 

            if parameter_g < 0.1 :
                parameter_g += 0.03
            elif parameter_g >= 0.1 and parameter_g < 1.0 :
                parameter_g += 0.3
            elif parameter_g >= 1.0 and parameter_g < 10.0 :
                parameter_g += 3.0
            else :
                parameter_g += 30.0

            key = str(parameter_l) + ',' + str(parameter_u) + str(',') + str(parameter_g)
            print key
            w = Optimization(0.01, parameter_u, parameter_g)
            # print Evaluation(w)
            if w is not None :
                Performace[key] =  Evaluation(w)
# Out:
# 1
# 0.03,0.02,0.02
# iterations:1 delta_A:50.7864989366 delta_w:0.00619637237643
# iterations:2 delta_A:0.124070421941 delta_w:1.90951980636e-05
# 2
# 0.03,0.02,0.04
# iterations:1 delta_A:32.125258124 delta_w:0.00434587374124
# iterations:2 delta_A:0.0307497628534 delta_w:5.5743477552e-06
# 3
# 0.03,0.02,0.06
# iterations:1 delta_A:28.1184395896 delta_w:0.00451755224547
# iterations:2 delta_A:0.0259395799657 delta_w:4.86777070091e-06
# 4
# 0.03,0.02,0.08
# iterations:1 delta_A:24.1245042214 delta_w:0.0027587247396
# iterations:2 delta_A:0.0162589884219 delta_w:2.32308186585e-06
# 5
# 0.03,0.02,0.1
# iterations:1 delta_A:20.408808132 delta_w:0.00254791235398
# iterations:2 delta_A:0.0114154848911 delta_w:1.71147994022e-06
# 6
# 0.03,0.02,0.2
# iterations:1 delta_A:10.9461510114 delta_w:0.00126415791365
# iterations:2 delta_A:0.00269609029634 delta_w:3.99781281336e-07
# 7
# 0.03,0.02,0.3
# iterations:1 delta_A:6.07112452023 delta_w:0.000798795026801
# 8
# 0.03,0.02,0.4
# iterations:1 delta_A:3.98679026325 delta_w:0.000395701456525
# 9
# 0.03,0.02,0.5
# iterations:1 delta_A:4.42163061302 delta_w:0.000518264413039
# 10
# 0.03,0.02,0.6
# iterations:1 delta_A:3.33081332519 delta_w:0.000389174069737
# 11
# 0.03,0.02,0.7
# iterations:1 delta_A:3.53256493464 delta_w:0.000430149022579
# 12
# 0.03,0.02,0.8
# iterations:1 delta_A:2.41467789939 delta_w:0.000273192315141
# 13
# 0.03,0.02,0.9
# iterations:1 delta_A:2.44995348951 delta_w:0.000301213638485
# 14
# 0.03,0.02,1.0
# iterations:1 delta_A:1.8797635534 delta_w:0.000213150494893
# 15
# 0.03,0.02,1.1
# iterations:1 delta_A:1.9213241071 delta_w:0.000264921515701
# 16
# 0.03,0.02,3.1
# iterations:1 delta_A:0.68419956855 delta_w:8.01442548235e-05
# 17
# 0.03,0.02,5.1
# iterations:1 delta_A:0.353153154472 delta_w:4.13744628948e-05
# 18
# 0.03,0.02,7.1
# iterations:1 delta_A:0.362510319405 delta_w:4.79593179977e-05
# 19
# 0.03,0.02,9.1
# iterations:1 delta_A:0.254815148836 delta_w:3.4446111302e-05
# 20
# 0.03,0.02,11.1
# iterations:1 delta_A:0.226295103997 delta_w:2.39834751163e-05
# 21
# 0.03,0.02,31.1
# iterations:1 delta_A:0.0592064784656 delta_w:7.53262919708e-06
# 22
# 0.03,0.02,51.1
# iterations:1 delta_A:0.0379972436146 delta_w:4.11107048312e-06
# 23
# 0.03,0.02,71.1
# iterations:1 delta_A:0.030965234054 delta_w:3.43124827912e-06
# 24
# 0.03,0.02,91.1
# iterations:1 delta_A:0.020212984082 delta_w:2.49022157082e-06
# 25
# 0.03,0.02,111.1
# iterations:1 delta_A:0.0184600305822 delta_w:2.24250765801e-06
# 26
# 0.03,0.04,0.02
# iterations:1 delta_A:66.4140937283 delta_w:0.0148416320964
# iterations:2 delta_A:0.54158970904 delta_w:0.000166024557591
# 27
# 0.03,0.04,0.04
# iterations:1 delta_A:51.0772990997 delta_w:0.0131063063466
# iterations:2 delta_A:0.260208947976 delta_w:8.9767068164e-05
# 28
# 0.03,0.04,0.06
# iterations:1 delta_A:46.0117099964 delta_w:0.00996837337012
# iterations:2 delta_A:0.147876306517 delta_w:4.41511534421e-05
# 29
# 0.03,0.04,0.08
# iterations:1 delta_A:41.7913380078 delta_w:0.00990909791808
# iterations:2 delta_A:0.134475114746 delta_w:4.15617606918e-05
# 30
# 0.03,0.04,0.1
# iterations:1 delta_A:31.3463620371 delta_w:0.00610877467022
# iterations:2 delta_A:0.0602176534495 delta_w:1.59372039758e-05
# 31
# 0.03,0.04,0.2
# iterations:1 delta_A:19.0387365988 delta_w:0.00468122482706
# iterations:2 delta_A:0.0174928661652 delta_w:5.55364777833e-06
# 32
# 0.03,0.04,0.3
# iterations:1 delta_A:14.5527432257 delta_w:0.00340617500254
# iterations:2 delta_A:0.0124148074749 delta_w:3.54504321058e-06
# 33
# 0.03,0.04,0.4
# iterations:1 delta_A:10.2726796855 delta_w:0.00293506807552
# iterations:2 delta_A:0.00615520571009 delta_w:2.35068117466e-06
# 34
# 0.03,0.04,0.5
# iterations:1 delta_A:7.65780161706 delta_w:0.00178961341868
# iterations:2 delta_A:0.00347665370373 delta_w:1.02671103718e-06
# 35
# 0.03,0.04,0.6
# iterations:1 delta_A:7.13780179199 delta_w:0.00180828679163
# iterations:2 delta_A:0.00291783935382 delta_w:9.23230631137e-07
# 36
# 0.03,0.04,0.7
# iterations:1 delta_A:5.57403598985 delta_w:0.00115156001559
# iterations:2 delta_A:0.00121457799435 delta_w:3.60551480727e-07
# 37
# 0.03,0.04,0.8
# iterations:1 delta_A:5.4092888563 delta_w:0.00114052744216
# iterations:2 delta_A:0.00155508169114 delta_w:3.95657610254e-07
# 38
# 0.03,0.04,0.9
# iterations:1 delta_A:5.02834843382 delta_w:0.00114886199429
# iterations:2 delta_A:0.00127581629499 delta_w:3.62119277516e-07
# 39
# 0.03,0.04,1.0
# iterations:1 delta_A:5.15781115635 delta_w:0.0013512840947
# iterations:2 delta_A:0.0015952414606 delta_w:4.62346642244e-07
# 40
# 0.03,0.04,1.1
# iterations:1 delta_A:3.8556079014 delta_w:0.000884936710446
# 41
# 0.03,0.04,3.1
# iterations:1 delta_A:1.05129208587 delta_w:0.000247440038264
# 42
# 0.03,0.04,5.1
# iterations:1 delta_A:0.780326030344 delta_w:0.000182240830607
# 43
# 0.03,0.04,7.1
# iterations:1 delta_A:0.657381734827 delta_w:0.000153589407555
# 44
# 0.03,0.04,9.1
# iterations:1 delta_A:0.48738163505 delta_w:0.00012106474454
# 45
# 0.03,0.04,11.1
# iterations:1 delta_A:0.408709402036 delta_w:8.63256172385e-05
# 46
# 0.03,0.04,31.1
# iterations:1 delta_A:0.134390560545 delta_w:3.13947747268e-05
# 47
# 0.03,0.04,51.1
# iterations:1 delta_A:0.0852432661288 delta_w:1.82264913392e-05
# 48
# 0.03,0.04,71.1
# iterations:1 delta_A:0.0576257919189 delta_w:1.33435032722e-05
# 49
# 0.03,0.04,91.1
# iterations:1 delta_A:0.0485209130491 delta_w:1.10570152244e-05
# 50
# 0.03,0.04,111.1
# iterations:1 delta_A:0.0352137374708 delta_w:8.22440866333e-06
# 51
# 0.03,0.06,0.02
# iterations:1 delta_A:72.7090915492 delta_w:0.0209076968067
# iterations:2 delta_A:1.05121284509 delta_w:0.000360914033048
# 52
# 0.03,0.06,0.04
# iterations:1 delta_A:60.4768724601 delta_w:0.0205879822596
# iterations:2 delta_A:0.645933286416 delta_w:0.000296638882233
# 53
# 0.03,0.06,0.06
# iterations:1 delta_A:48.7146931046 delta_w:0.0170482112803
# iterations:2 delta_A:0.288779050363 delta_w:0.000133348439626
# 54
# 0.03,0.06,0.08
# iterations:1 delta_A:48.8897624387 delta_w:0.0162220228081
# iterations:2 delta_A:0.331052705788 delta_w:0.000140032016426
# 55
# 0.03,0.06,0.1
# iterations:1 delta_A:42.5549887529 delta_w:0.016616682068
# iterations:2 delta_A:0.237641170714 delta_w:0.000105445097569
# 56
# 0.03,0.06,0.2
# iterations:1 delta_A:26.8748473868 delta_w:0.0106082772437
# iterations:2 delta_A:0.0666529008019 delta_w:3.45727125758e-05
# 57
# 0.03,0.06,0.3
# iterations:1 delta_A:20.5407486549 delta_w:0.00733424937674
# iterations:2 delta_A:0.0382192263375 delta_w:1.66132338424e-05
# 58
# 0.03,0.06,0.4
# iterations:1 delta_A:13.6377655656 delta_w:0.0043157376959
# iterations:2 delta_A:0.0163475944711 delta_w:6.45056783908e-06
# 59
# 0.03,0.06,0.5
# iterations:1 delta_A:11.5110368254 delta_w:0.00413242493396
# iterations:2 delta_A:0.0108265565483 delta_w:4.96459122036e-06
# 60
# 0.03,0.06,0.6
# iterations:1 delta_A:14.0898737604 delta_w:0.0054263640229
# iterations:2 delta_A:0.0162506266651 delta_w:7.1795968424e-06
# 61
# 0.03,0.06,0.7
# iterations:1 delta_A:9.15989529267 delta_w:0.00320278914107
# iterations:2 delta_A:0.00614553371411 delta_w:2.52737390772e-06
# 62
# 0.03,0.06,0.8
# iterations:1 delta_A:6.36171862742 delta_w:0.00242852469847
# iterations:2 delta_A:0.00468128916823 delta_w:2.21876506476e-06
# 63
# 0.03,0.06,0.9
# iterations:1 delta_A:6.38692821961 delta_w:0.00224950338287
# iterations:2 delta_A:0.00411651380986 delta_w:1.63200554091e-06
# 64
# 0.03,0.06,1.0
# iterations:1 delta_A:6.5962838947 delta_w:0.00205169983832
# iterations:2 delta_A:0.0038970160153 delta_w:1.55585970966e-06
# 65
# 0.03,0.06,1.1
# iterations:1 delta_A:5.67198015899 delta_w:0.00210454557444
# iterations:2 delta_A:0.00254384075911 delta_w:1.11342018686e-06
# 66
# 0.03,0.06,3.1
# iterations:1 delta_A:1.7163573307 delta_w:0.000587384227933
# 67
# 0.03,0.06,5.1
# iterations:1 delta_A:1.21198219721 delta_w:0.000523745522766
# 68
# 0.03,0.06,7.1
# iterations:1 delta_A:0.78687054262 delta_w:0.000280297877531
# 69
# 0.03,0.06,9.1
# iterations:1 delta_A:0.685741186959 delta_w:0.000233375679001
# 70
# 0.03,0.06,11.1
# iterations:1 delta_A:0.522030356433 delta_w:0.000189966598223
# 71
# 0.03,0.06,31.1
# iterations:1 delta_A:0.221271259648 delta_w:8.61617284406e-05
# 72
# 0.03,0.06,51.1
# iterations:1 delta_A:0.0998654763781 delta_w:3.68388929392e-05
# 73
# 0.03,0.06,71.1
# iterations:1 delta_A:0.0658390921683 delta_w:1.97269550901e-05
# 74
# 0.03,0.06,91.1
# iterations:1 delta_A:0.0640663244508 delta_w:2.43699906121e-05
# 75
# 0.03,0.06,111.1
# iterations:1 delta_A:0.0643621715393 delta_w:2.43775104846e-05
# 76
# 0.03,0.08,0.02
# iterations:1 delta_A:75.7640234008 delta_w:0.0338171708608
# iterations:2 delta_A:2.08812847099 delta_w:0.000951160035436
# 77
# 0.03,0.08,0.04
# iterations:1 delta_A:63.6537243629 delta_w:0.0268800454752
# iterations:2 delta_A:0.676036912154 delta_w:0.00041660049336
# 78
# 0.03,0.08,0.06
# iterations:1 delta_A:56.3392967184 delta_w:0.0227300714416
# iterations:2 delta_A:0.761205981871 delta_w:0.000415716267386
# 79
# 0.03,0.08,0.08
# iterations:1 delta_A:51.5811934583 delta_w:0.0236989980475
# iterations:2 delta_A:0.540295808395 delta_w:0.000299993685283
# 80
# 0.03,0.08,0.1
# iterations:1 delta_A:48.1465485248 delta_w:0.0213167143801
# iterations:2 delta_A:0.389446647909 delta_w:0.000225891011648
# 81
# 0.03,0.08,0.2
# iterations:1 delta_A:35.5294595174 delta_w:0.015990845674
# iterations:2 delta_A:0.165121199109 delta_w:8.59030684014e-05
# 82
# 0.03,0.08,0.3
# iterations:1 delta_A:27.8118408268 delta_w:0.0121978775566
# iterations:2 delta_A:0.0939560468237 delta_w:5.46538469441e-05
# 83
# 0.03,0.08,0.4
# iterations:1 delta_A:20.6183172814 delta_w:0.0113702537665
# iterations:2 delta_A:0.0448080381957 delta_w:3.24730633148e-05
# 84
# 0.03,0.08,0.5
# iterations:1 delta_A:15.7697715789 delta_w:0.0075460033914
# iterations:2 delta_A:0.0267512301916 delta_w:1.66955785496e-05
# 85
# 0.03,0.08,0.6
# iterations:1 delta_A:19.7467240019 delta_w:0.00902517633554
# iterations:2 delta_A:0.0408777227211 delta_w:2.17208948147e-05
# 86
# 0.03,0.08,0.7
# iterations:1 delta_A:12.2779144135 delta_w:0.00565480267202
# iterations:2 delta_A:0.0164858850368 delta_w:9.1471106048e-06
# 87
# 0.03,0.08,0.8
# iterations:1 delta_A:9.06872694696 delta_w:0.00428891555173
# iterations:2 delta_A:0.00949392572117 delta_w:5.52155629307e-06
# 88
# 0.03,0.08,0.9
# iterations:1 delta_A:8.24006336377 delta_w:0.00378835839349
# iterations:2 delta_A:0.00732855548109 delta_w:4.37325215446e-06
# 89
# 0.03,0.08,1.0
# iterations:1 delta_A:6.66991704162 delta_w:0.00305766408417
# iterations:2 delta_A:0.00488301866214 delta_w:2.71522910825e-06
# 90
# 0.03,0.08,1.1
# iterations:1 delta_A:7.32782664638 delta_w:0.00299862380764
# iterations:2 delta_A:0.00585566518224 delta_w:2.96330851309e-06
# 91
# 0.03,0.08,3.1
# iterations:1 delta_A:2.34976662964 delta_w:0.00112136661808
# iterations:2 delta_A:0.000733967621372 delta_w:4.17599108344e-07
# 92
# 0.03,0.08,5.1
# iterations:1 delta_A:1.79006980557 delta_w:0.000856110782408
# 93
# 0.03,0.08,7.1
# iterations:1 delta_A:1.30812099526 delta_w:0.000580747348274
# 94
# 0.03,0.08,9.1
# iterations:1 delta_A:0.984623965857 delta_w:0.000450635718637
# 95
# 0.03,0.08,11.1
# iterations:1 delta_A:0.820125204439 delta_w:0.00039242644011
# 96
# 0.03,0.08,31.1
# iterations:1 delta_A:0.234170813189 delta_w:0.00012400411113
# 97
# 0.03,0.08,51.1
# iterations:1 delta_A:0.180361519173 delta_w:8.8523941909e-05
# 98
# 0.03,0.08,71.1
# iterations:1 delta_A:0.141939774015 delta_w:6.75682002091e-05
# 99
# 0.03,0.08,91.1
# iterations:1 delta_A:0.0926621913014 delta_w:4.20810082299e-05
# 100
# 0.03,0.08,111.1
# iterations:1 delta_A:0.0694354500453 delta_w:3.1717616735e-05
# 101
# 0.03,0.1,0.02
# iterations:1 delta_A:78.4788809912 delta_w:0.0468058820398
# iterations:2 delta_A:2.97824923632 delta_w:0.00169673103496
# iterations:3 delta_A:0.145273577157 delta_w:8.97647598117e-05
# 102
# 0.03,0.1,0.04
# iterations:1 delta_A:69.3950781354 delta_w:0.042085340183
# iterations:2 delta_A:1.52854272879 delta_w:0.00116315006582
# iterations:3 delta_A:0.0536221247927 delta_w:4.3251105251e-05
# 103
# 0.03,0.1,0.06
# iterations:1 delta_A:63.0496561896 delta_w:0.0332213987333
# iterations:2 delta_A:1.12806474584 delta_w:0.000822520555336
# 104
# 0.03,0.1,0.08
# iterations:1 delta_A:55.4037874272 delta_w:0.0285580377122
# iterations:2 delta_A:0.518230956651 delta_w:0.00041321365425
# 105
# 0.03,0.1,0.1
# iterations:1 delta_A:53.393239232 delta_w:0.0305585362869
# iterations:2 delta_A:0.808985582626 delta_w:0.000620568608087
# 106
# 0.03,0.1,0.2
# iterations:1 delta_A:36.9820898725 delta_w:0.0205628731923
# iterations:2 delta_A:0.255991205221 delta_w:0.000178398277684
# 107
# 0.03,0.1,0.3
# iterations:1 delta_A:26.7213532885 delta_w:0.0162561531592
# iterations:2 delta_A:0.102481440899 delta_w:8.16771852284e-05
# 108
# 0.03,0.1,0.4
# iterations:1 delta_A:22.2295275385 delta_w:0.0130229288493
# iterations:2 delta_A:0.0770848415473 delta_w:5.53128655159e-05
# 109
# 0.03,0.1,0.5
# iterations:1 delta_A:21.4783016131 delta_w:0.0130924936795
# iterations:2 delta_A:0.0662845701865 delta_w:4.93788983682e-05
# 110
# 0.03,0.1,0.6
# iterations:1 delta_A:15.7442788355 delta_w:0.00828791569794
# iterations:2 delta_A:0.0333861270921 delta_w:2.25205787702e-05
# 111
# 0.03,0.1,0.7
# iterations:1 delta_A:17.2450297679 delta_w:0.0100509419784
# iterations:2 delta_A:0.0430114831013 delta_w:2.9119632063e-05
# 112
# 0.03,0.1,0.8
# iterations:1 delta_A:14.6234404094 delta_w:0.00873564888813
# iterations:2 delta_A:0.0302762319632 delta_w:1.99508501044e-05
# 113
# 0.03,0.1,0.9
# iterations:1 delta_A:11.6087784377 delta_w:0.00665892170333
# iterations:2 delta_A:0.020329959101 delta_w:1.31648561689e-05
# 114
# 0.03,0.1,1.0
# iterations:1 delta_A:9.20743226223 delta_w:0.00578607417226
# iterations:2 delta_A:0.0133475608416 delta_w:1.03681493319e-05
# 115
# 0.03,0.1,1.1
# iterations:1 delta_A:9.77464475968 delta_w:0.00588320279536
# iterations:2 delta_A:0.0137500456068 delta_w:1.03923852771e-05
# 116
# 0.03,0.1,3.1
# iterations:1 delta_A:3.06919539654 delta_w:0.00172477403901
# iterations:2 delta_A:0.00134497558109 delta_w:9.69744093024e-07
# 117
# 0.03,0.1,5.1
# iterations:1 delta_A:2.31747808421 delta_w:0.00132418283453
# iterations:2 delta_A:0.000641604267048 delta_w:4.98853439991e-07
# 118
# 0.03,0.1,7.1
# iterations:1 delta_A:1.20604017974 delta_w:0.000781502414778
# 119
# 0.03,0.1,9.1
# iterations:1 delta_A:1.32498575581 delta_w:0.000756982040441
# 120
# 0.03,0.1,11.1
# iterations:1 delta_A:0.882957818213 delta_w:0.000462191189899
# 121
# 0.03,0.1,31.1
# iterations:1 delta_A:0.343621012866 delta_w:0.000188514000942
# 122
# 0.03,0.1,51.1
# iterations:1 delta_A:0.229457512786 delta_w:0.000117609058264
# 123
# 0.03,0.1,71.1
# iterations:1 delta_A:0.148244797585 delta_w:7.92897703828e-05
# 124
# 0.03,0.1,91.1
# iterations:1 delta_A:0.131954219031 delta_w:8.44441113847e-05
# 125
# 0.03,0.1,111.1
# iterations:1 delta_A:0.0953041803627 delta_w:6.0911319122e-05
# 126
# 0.03,0.2,0.02
# iterations:1 delta_A:77.0058226752 delta_w:0.0844875285443
# iterations:2 delta_A:6.0874389641 delta_w:0.00525841640815
# iterations:3 delta_A:0.60871194023 delta_w:0.00051485138282
# 127
# 0.03,0.2,0.04
# iterations:1 delta_A:78.1804688192 delta_w:0.0866809843337
# iterations:2 delta_A:4.9342372729 delta_w:0.00522610446637
# iterations:3 delta_A:0.399984631221 delta_w:0.000439688534347
# 128
# 0.03,0.2,0.06
# iterations:1 delta_A:72.457364937 delta_w:0.0707797952735
# iterations:2 delta_A:4.01473345389 delta_w:0.00465192040281
# iterations:3 delta_A:0.36865811874 delta_w:0.000450146468218
# 129
# 0.03,0.2,0.08
# iterations:1 delta_A:65.8667308156 delta_w:0.0814920825718
# iterations:2 delta_A:2.25646868108 delta_w:0.00396994242903
# iterations:3 delta_A:0.14389164187 delta_w:0.000276680804013
# 130
# 0.03,0.2,0.1
# iterations:1 delta_A:61.9447499191 delta_w:0.0653233473909
# iterations:2 delta_A:2.28003737631 delta_w:0.00293218058404
# iterations:3 delta_A:0.136183244771 delta_w:0.000169167557698
# 131
# 0.03,0.2,0.2
# iterations:1 delta_A:51.3533439408 delta_w:0.0523122520222
# iterations:2 delta_A:1.18699754968 delta_w:0.00173810065697
# iterations:3 delta_A:0.0463718145664 delta_w:6.83012997015e-05
# 132
# 0.03,0.2,0.3
# iterations:1 delta_A:43.3908615915 delta_w:0.0474809370355
# iterations:2 delta_A:0.705095857466 delta_w:0.00102758569782
# iterations:3 delta_A:0.0185652353696 delta_w:2.70100969827e-05
# 133
# 0.03,0.2,0.4
# iterations:1 delta_A:40.5412379983 delta_w:0.0470180141846
# iterations:2 delta_A:0.574305549394 delta_w:0.000746190429161
# 134
# 0.03,0.2,0.5
# iterations:1 delta_A:32.8468130947 delta_w:0.0362899894827
# iterations:2 delta_A:0.278400841948 delta_w:0.000399983598199
# 135
# 0.03,0.2,0.6
# iterations:1 delta_A:29.4639623703 delta_w:0.0328711893662
# iterations:2 delta_A:0.210328500957 delta_w:0.000324829578238
# 136
# 0.03,0.2,0.7
# iterations:1 delta_A:28.0370339976 delta_w:0.0338178956882
# iterations:2 delta_A:0.228386107616 delta_w:0.000323504910366
# 137
# 0.03,0.2,0.8
# iterations:1 delta_A:27.8102323954 delta_w:0.0347465531256
# iterations:2 delta_A:0.253579656553 delta_w:0.000378933937223
# 138
# 0.03,0.2,0.9
# iterations:1 delta_A:25.8049369121 delta_w:0.0334679712152
# iterations:2 delta_A:0.207543366733 delta_w:0.000297367165226
# 139
# 0.03,0.2,1.0
# iterations:1 delta_A:22.9161412695 delta_w:0.0255596544146
# iterations:2 delta_A:0.134874422623 delta_w:0.000196933665183
# 140
# 0.03,0.2,1.1
# iterations:1 delta_A:20.4725708782 delta_w:0.0294925197249
# iterations:2 delta_A:0.118944705137 delta_w:0.00021256319868
# 141
# 0.03,0.2,3.1
# iterations:1 delta_A:6.19977718997 delta_w:0.00704176639522
# iterations:2 delta_A:0.0115886260487 delta_w:1.57454733523e-05
# 142
# 0.03,0.2,5.1
# iterations:1 delta_A:3.48324951457 delta_w:0.00339761172775
# iterations:2 delta_A:0.00325123121181 delta_w:4.72362055707e-06
# 143
# 0.03,0.2,7.1
# iterations:1 delta_A:2.55068874545 delta_w:0.00260104673995
# iterations:2 delta_A:0.00171943146164 delta_w:2.3172916207e-06
# 144
# 0.03,0.2,9.1
# iterations:1 delta_A:2.1535201396 delta_w:0.00224507095842
# iterations:2 delta_A:0.0012342547389 delta_w:1.52207402523e-06
# 145
# 0.03,0.2,11.1
# iterations:1 delta_A:1.70611793275 delta_w:0.00193774792971
# iterations:2 delta_A:0.000642318021548 delta_w:1.01330067252e-06
# 146
# 0.03,0.2,31.1
# iterations:1 delta_A:0.79842703335 delta_w:0.000928342863223
# 147
# 0.03,0.2,51.1
# iterations:1 delta_A:0.409340405826 delta_w:0.000483361395461
# 148
# 0.03,0.2,71.1
# iterations:1 delta_A:0.290220110998 delta_w:0.000414893641651
# 149
# 0.03,0.2,91.1
# iterations:1 delta_A:0.266252268025 delta_w:0.00029530554629
# 150
# 0.03,0.2,111.1
# iterations:1 delta_A:0.198170523574 delta_w:0.000244441253423
# 151
# 0.03,0.3,0.02
# iterations:1 delta_A:82.2313115231 delta_w:0.113396404604
# iterations:2 delta_A:11.0386504692 delta_w:0.0110624412546
# iterations:3 delta_A:1.58300077363 delta_w:0.00161470345287
# iterations:4 delta_A:0.246097551495 delta_w:0.000260089254811
# 152
# 0.03,0.3,0.04
# iterations:1 delta_A:83.3105654372 delta_w:0.126407040609
# iterations:2 delta_A:10.2505662369 delta_w:0.0137693888262
# iterations:3 delta_A:1.61513425456 delta_w:0.00240916744749
# iterations:4 delta_A:0.269640652573 delta_w:0.000422163351418
# 153
# 0.03,0.3,0.06
# iterations:1 delta_A:79.4438809609 delta_w:0.121491752862
# iterations:2 delta_A:8.1466839879 delta_w:0.0128118188325
# iterations:3 delta_A:1.11505901865 delta_w:0.00197439461451
# iterations:4 delta_A:0.164867865483 delta_w:0.00030887642728
# 154
# 0.03,0.3,0.08
# iterations:1 delta_A:70.4960026378 delta_w:0.102561075959
# iterations:2 delta_A:4.36737508947 delta_w:0.00737036847872
# iterations:3 delta_A:0.440737735917 delta_w:0.000781164124845
# 155
# 0.03,0.3,0.1
# iterations:1 delta_A:68.2824051022 delta_w:0.123507621661
# iterations:2 delta_A:5.09230714739 delta_w:0.00984355610117
# iterations:3 delta_A:0.574443936844 delta_w:0.0011449528658
# iterations:4 delta_A:0.0692225589928 delta_w:0.000143258381591
# 156
# 0.03,0.3,0.2
# iterations:1 delta_A:57.1350765932 delta_w:0.0982852923463
# iterations:2 delta_A:2.44790718003 delta_w:0.00595034872439
# iterations:3 delta_A:0.170700759948 delta_w:0.000446821399558
# 157
# 0.03,0.3,0.3
# iterations:1 delta_A:52.0981516219 delta_w:0.0846308320215
# iterations:2 delta_A:2.03369157102 delta_w:0.00447220369636
# iterations:3 delta_A:0.13260063939 delta_w:0.000294880882074
# 158
# 0.03,0.3,0.4
# iterations:1 delta_A:50.6930023877 delta_w:0.0890215714664
# iterations:2 delta_A:1.8014284021 delta_w:0.00399684219671
# iterations:3 delta_A:0.0879564775663 delta_w:0.000197177986755
# 159
# 0.03,0.3,0.5
# iterations:1 delta_A:44.6156701804 delta_w:0.0732527927128
# iterations:2 delta_A:0.978877708546 delta_w:0.00201594185147
# iterations:3 delta_A:0.0367286723179 delta_w:7.96050962632e-05
# 160
# 0.03,0.3,0.6
# iterations:1 delta_A:39.3655465024 delta_w:0.0806022736784
# iterations:2 delta_A:0.901464784124 delta_w:0.00242570373325
# iterations:3 delta_A:0.0290478964129 delta_w:8.1699087793e-05
# 161
# 0.03,0.3,0.7
# iterations:1 delta_A:38.5795032483 delta_w:0.0632102368931
# iterations:2 delta_A:0.734523588182 delta_w:0.00148519000054
# iterations:3 delta_A:0.0187874333713 delta_w:3.86399534169e-05
# 162
# 0.03,0.3,0.8
# iterations:1 delta_A:33.9532207061 delta_w:0.0607104459155
# iterations:2 delta_A:0.490067250687 delta_w:0.0011465197013
# iterations:3 delta_A:0.0100951564358 delta_w:2.48387080708e-05
# 163
# 0.03,0.3,0.9
# iterations:1 delta_A:29.1959928291 delta_w:0.0494808720277
# iterations:2 delta_A:0.435475641923 delta_w:0.000906752528388
# 164
# 0.03,0.3,1.0
# iterations:1 delta_A:28.1349807657 delta_w:0.0475261493056
# iterations:2 delta_A:0.297275999726 delta_w:0.00067680781574
# 165
# 0.03,0.3,1.1
# iterations:1 delta_A:28.8385683147 delta_w:0.0598177241644
# iterations:2 delta_A:0.355664523482 delta_w:0.000808312015659
# 166
# 0.03,0.3,3.1
# iterations:1 delta_A:10.8649444933 delta_w:0.0197048031586
# iterations:2 delta_A:0.0510314049883 delta_w:0.000118597394175
# 167
# 0.03,0.3,5.1
# iterations:1 delta_A:5.37256390818 delta_w:0.0095159649788
# iterations:2 delta_A:0.0133943160701 delta_w:2.7938179697e-05
# 168
# 0.03,0.3,7.1
# iterations:1 delta_A:4.57267120898 delta_w:0.00710808442139
# iterations:2 delta_A:0.00786446510024 delta_w:1.70206942492e-05
# 169
# 0.03,0.3,9.1
# iterations:1 delta_A:3.87618943538 delta_w:0.00724767102597
# iterations:2 delta_A:0.00701575707979 delta_w:1.50392836848e-05
# 170
# 0.03,0.3,11.1
# iterations:1 delta_A:3.0401804666 delta_w:0.0067601903206
# iterations:2 delta_A:0.00403897634185 delta_w:1.05270055398e-05
# 171
# 0.03,0.3,31.1
# iterations:1 delta_A:0.938614838203 delta_w:0.00165756797996
# iterations:2 delta_A:0.000335087228546 delta_w:8.02990330403e-07
# 172
# 0.03,0.3,51.1
# iterations:1 delta_A:0.576971819381 delta_w:0.000939446943724
# 173
# 0.03,0.3,71.1
# iterations:1 delta_A:0.427865694318 delta_w:0.000752170977784
# 174
# 0.03,0.3,91.1
# iterations:1 delta_A:0.291735458192 delta_w:0.000561110691875
# 175
# 0.03,0.3,111.1
# iterations:1 delta_A:0.238477900702 delta_w:0.000383477537578
# 176
# 0.03,0.4,0.02
# iterations:1 delta_A:87.2451550771 delta_w:0.210578122234
# iterations:2 delta_A:21.9689054997 delta_w:0.0310057249082
# iterations:3 delta_A:4.93611765753 delta_w:0.00584887054193
# iterations:4 delta_A:1.03061630569 delta_w:0.00124472414361
# iterations:5 delta_A:0.217161291571 delta_w:0.000267056272474
# 177
# 0.03,0.4,0.04
# iterations:1 delta_A:80.4715752365 delta_w:0.141572099967
# iterations:2 delta_A:9.7595328939 delta_w:0.0156509996638
# iterations:3 delta_A:1.51549958778 delta_w:0.00246508636854
# iterations:4 delta_A:0.270553830345 delta_w:0.000476758508134
# 178
# 0.03,0.4,0.06
# iterations:1 delta_A:74.6460538688 delta_w:0.182089026633
# iterations:2 delta_A:9.16612116025 delta_w:0.0205263315931
# iterations:3 delta_A:1.6193037361 delta_w:0.00379615288451
# iterations:4 delta_A:0.316050086553 delta_w:0.000738091677195
# 179
# 0.03,0.4,0.08
# iterations:1 delta_A:78.155307058 delta_w:0.186264725066
# iterations:2 delta_A:7.60677886995 delta_w:0.0179626442607
# iterations:3 delta_A:1.117721026 delta_w:0.00290527198199
# iterations:4 delta_A:0.195097947449 delta_w:0.000527800714467
# 180
# 0.03,0.4,0.1
# iterations:1 delta_A:76.8260499483 delta_w:0.137148562129
# iterations:2 delta_A:8.33479505802 delta_w:0.0206882446623
# iterations:3 delta_A:1.31746200651 delta_w:0.00356738122453
# iterations:4 delta_A:0.228813976144 delta_w:0.00063876240535
# 181
# 0.03,0.4,0.2
# iterations:1 delta_A:64.5024447841 delta_w:0.135224484101
# iterations:2 delta_A:4.24452547033 delta_w:0.0123263786812
# iterations:3 delta_A:0.492050487715 delta_w:0.00157048495175
# iterations:4 delta_A:0.0622910311239 delta_w:0.000208558537262
# 182
# 0.03,0.4,0.3
# iterations:1 delta_A:55.7397572118 delta_w:0.139315603858
# iterations:2 delta_A:3.21474376287 delta_w:0.0098622593027
# iterations:3 delta_A:0.335848572753 delta_w:0.00100498776578
# iterations:4 delta_A:0.0384883377918 delta_w:0.000112633614577
# 183
# 0.03,0.4,0.4
# iterations:1 delta_A:53.9996564656 delta_w:0.11550895716
# iterations:2 delta_A:2.56825511053 delta_w:0.00765806870326
# iterations:3 delta_A:0.207859773478 delta_w:0.000625926011035
# 184
# 0.03,0.4,0.5
# iterations:1 delta_A:50.4913521054 delta_w:0.096529907983
# iterations:2 delta_A:2.18415310062 delta_w:0.00567071815409
# iterations:3 delta_A:0.150105938576 delta_w:0.000388560634748
# 185
# 0.03,0.4,0.6
# iterations:1 delta_A:45.3472980267 delta_w:0.0973261461118
# iterations:2 delta_A:1.98594951284 delta_w:0.00528937791518
# iterations:3 delta_A:0.125177379198 delta_w:0.000339481276499
# 186
# 0.03,0.4,0.7
# iterations:1 delta_A:42.5618886817 delta_w:0.104609868377
# iterations:2 delta_A:1.38606035729 delta_w:0.00414456497454
# iterations:3 delta_A:0.0700180357107 delta_w:0.000210170142435
# 187
# 0.03,0.4,0.8
# iterations:1 delta_A:40.0622382783 delta_w:0.0847694721488
# iterations:2 delta_A:1.29645787096 delta_w:0.00371851305557
# iterations:3 delta_A:0.0590022344933 delta_w:0.000173579689667
# 188
# 0.03,0.4,0.9
# iterations:1 delta_A:37.1713389543 delta_w:0.0883498128672
# iterations:2 delta_A:0.769303697829 delta_w:0.00226362350384
# iterations:3 delta_A:0.0214699850332 delta_w:6.63764468035e-05
# 189
# 0.03,0.4,1.0
# iterations:1 delta_A:33.9547253327 delta_w:0.0809403862652
# iterations:2 delta_A:0.63602945477 delta_w:0.00200367562498
# iterations:3 delta_A:0.0192183121849 delta_w:6.19430021901e-05
# 190
# 0.03,0.4,1.1
# iterations:1 delta_A:33.6269044694 delta_w:0.0864025584892
# iterations:2 delta_A:0.723128279513 delta_w:0.00212464370831
# iterations:3 delta_A:0.0217993952055 delta_w:6.17501933096e-05
# 191
# 0.03,0.4,3.1
# iterations:1 delta_A:11.6188960278 delta_w:0.0238732411184
# iterations:2 delta_A:0.0716155198125 delta_w:0.000188309839313
# 192
# 0.03,0.4,5.1
# iterations:1 delta_A:8.53975971364 delta_w:0.0190764004385
# iterations:2 delta_A:0.0363575459208 delta_w:0.000107944235624
# 193
# 0.03,0.4,7.1
# iterations:1 delta_A:6.51190344588 delta_w:0.0161318362433
# iterations:2 delta_A:0.0236147991308 delta_w:6.75533625347e-05
# 194
# 0.03,0.4,9.1
# iterations:1 delta_A:4.38959871014 delta_w:0.0106651507596
# iterations:2 delta_A:0.0126135440511 delta_w:3.95992065591e-05
# 195
# 0.03,0.4,11.1
# iterations:1 delta_A:3.96045543978 delta_w:0.00845823903605
# iterations:2 delta_A:0.00889811470243 delta_w:2.3539069945e-05
# 196
# 0.03,0.4,31.1
# iterations:1 delta_A:1.35465829229 delta_w:0.0032326947817
# iterations:2 delta_A:0.000911352148826 delta_w:2.63557459208e-06
# 197
# 0.03,0.4,51.1
# iterations:1 delta_A:0.826061015466 delta_w:0.00191618841832
# iterations:2 delta_A:0.00045898874803 delta_w:1.29839647397e-06
# 198
# 0.03,0.4,71.1
# iterations:1 delta_A:0.522207859243 delta_w:0.00132145155841
# iterations:2 delta_A:0.000139415835585 delta_w:4.20115694489e-07
# 199
# 0.03,0.4,91.1
# iterations:1 delta_A:0.374896677464 delta_w:0.000835216837435
# 200
# 0.03,0.4,111.1
# iterations:1 delta_A:0.322310048435 delta_w:0.000760079380981
# 201
# 0.03,0.5,0.02
# iterations:1 delta_A:82.2016095304 delta_w:0.250333677371
# iterations:2 delta_A:20.3030219557 delta_w:0.0354687578442
# iterations:3 delta_A:5.68243275825 delta_w:0.00893336098123
# iterations:4 delta_A:1.56745394529 delta_w:0.00248432459424
# iterations:5 delta_A:0.439675023989 delta_w:0.000699629014436
# 202
# 0.03,0.5,0.04
# iterations:1 delta_A:85.1424187607 delta_w:0.234052271312
# iterations:2 delta_A:19.4279885125 delta_w:0.037159810508
# iterations:3 delta_A:4.59059332079 delta_w:0.00888191806646
# iterations:4 delta_A:1.15682505751 delta_w:0.00228209208695
# iterations:5 delta_A:0.303326498799 delta_w:0.000603115632623
# 203
# 0.03,0.5,0.06
# iterations:1 delta_A:80.2540750518 delta_w:0.173530229008
# iterations:2 delta_A:13.9217369338 delta_w:0.0327979300827
# iterations:3 delta_A:3.45347001074 delta_w:0.00886641267775
# iterations:4 delta_A:0.926917696055 delta_w:0.00253560837131
# iterations:5 delta_A:0.256678818952 delta_w:0.000740353323509
# 204
# 0.03,0.5,0.08
# iterations:1 delta_A:79.6856004672 delta_w:0.252592674752
# iterations:2 delta_A:15.7214475804 delta_w:0.0392073253586
# iterations:3 delta_A:3.4122771115 delta_w:0.00853910357097
# iterations:4 delta_A:0.784537002687 delta_w:0.00198852979238
# iterations:5 delta_A:0.184998535089 delta_w:0.000475743011966
# 205
# 0.03,0.5,0.1
# iterations:1 delta_A:74.5948077876 delta_w:0.183989988911
# iterations:2 delta_A:10.2729149217 delta_w:0.0264590900158
# iterations:3 delta_A:2.13846457175 delta_w:0.00581042512947
# iterations:4 delta_A:0.504485018007 delta_w:0.00143053646524
# iterations:5 delta_A:0.126424628796 delta_w:0.000373671972784
# 206
# 0.03,0.5,0.2
# iterations:1 delta_A:65.198773184 delta_w:0.188710733371
# iterations:2 delta_A:7.4622922308 delta_w:0.0243160847221
# iterations:3 delta_A:1.48296428104 delta_w:0.00478042364274
# iterations:4 delta_A:0.319930725997 delta_w:0.00102407137524
# iterations:5 delta_A:0.0707851239382 delta_w:0.000227163252575
# 207
# 0.03,0.5,0.3
# iterations:1 delta_A:63.6010788287 delta_w:0.165331041395
# iterations:2 delta_A:5.23798433001 delta_w:0.0178180606709
# iterations:3 delta_A:0.704637353042 delta_w:0.00243738811241
# iterations:4 delta_A:0.103224365167 delta_w:0.000359850511243
# 208
# 0.03,0.5,0.4
# iterations:1 delta_A:60.9551055659 delta_w:0.170499378252
# iterations:2 delta_A:6.01120886161 delta_w:0.0199533661927
# iterations:3 delta_A:0.850813151427 delta_w:0.00288426158669
# iterations:4 delta_A:0.123988591684 delta_w:0.000426325006075
# 209
# 0.03,0.5,0.5
# iterations:1 delta_A:55.0283260028 delta_w:0.145959459177
# iterations:2 delta_A:2.84746967644 delta_w:0.0108153662644
# iterations:3 delta_A:0.259112584828 delta_w:0.0010191949719
# iterations:4 delta_A:0.0269364315659 delta_w:0.000106223029652
# 210
# 0.03,0.5,0.6
# iterations:1 delta_A:52.8323829276 delta_w:0.142496983355
# iterations:2 delta_A:3.54389121144 delta_w:0.0124814420484
# iterations:3 delta_A:0.332554642061 delta_w:0.00121800820113
# iterations:4 delta_A:0.0326608594019 delta_w:0.000120856174807
# 211
# 0.03,0.5,0.7
# iterations:1 delta_A:44.6146214208 delta_w:0.135005881444
# iterations:2 delta_A:2.0585613236 delta_w:0.00865274491312
# iterations:3 delta_A:0.144883601044 delta_w:0.00061846994627
# 212
# 0.03,0.5,0.8
# iterations:1 delta_A:40.9225093594 delta_w:0.117725982653
# iterations:2 delta_A:1.49982437083 delta_w:0.00581376449808
# iterations:3 delta_A:0.0856428996063 delta_w:0.000368902640658
# 213
# 0.03,0.5,0.9
# iterations:1 delta_A:40.5259515666 delta_w:0.102860294605
# iterations:2 delta_A:1.18643792403 delta_w:0.00423635590954
# iterations:3 delta_A:0.063383192668 delta_w:0.000234632500988
# 214
# 0.03,0.5,1.0
# iterations:1 delta_A:36.0767500585 delta_w:0.0918165860926
# iterations:2 delta_A:1.12681004549 delta_w:0.00396497033091
# iterations:3 delta_A:0.0557605296026 delta_w:0.000205717071479
# 215
# 0.03,0.5,1.1
# iterations:1 delta_A:39.9048598082 delta_w:0.102576171737
# iterations:2 delta_A:1.28271618654 delta_w:0.004273981364
# iterations:3 delta_A:0.0611860583716 delta_w:0.000204417474057
# 216
# 0.03,0.5,3.1
# iterations:1 delta_A:16.7036942824 delta_w:0.0434934990045
# iterations:2 delta_A:0.185624152794 delta_w:0.00059339734488
# 217
# 0.03,0.5,5.1
# iterations:1 delta_A:10.5719196836 delta_w:0.0345798629499
# iterations:2 delta_A:0.072334087162 delta_w:0.000290746529848
# 218
# 0.03,0.5,7.1
# iterations:1 delta_A:6.89298605648 delta_w:0.0196604404078
# iterations:2 delta_A:0.0257740289754 delta_w:9.09551942586e-05
# 219
# 0.03,0.5,9.1
# iterations:1 delta_A:4.72104353297 delta_w:0.0135814224577
# iterations:2 delta_A:0.0120245034154 delta_w:4.91989854927e-05
# 220
# 0.03,0.5,11.1
# iterations:1 delta_A:4.66381426285 delta_w:0.0130080582391
# iterations:2 delta_A:0.0152404657544 delta_w:5.39618937363e-05
# 221
# 0.03,0.5,31.1
# iterations:1 delta_A:1.80345020863 delta_w:0.00518837882802
# iterations:2 delta_A:0.00203887379119 delta_w:7.06077018647e-06
# 222
# 0.03,0.5,51.1
# iterations:1 delta_A:1.17693677893 delta_w:0.0035526963178
# iterations:2 delta_A:0.00083694933881 delta_w:3.08276174096e-06
# 223
# 0.03,0.5,71.1
# iterations:1 delta_A:0.773156574221 delta_w:0.00219428471591
# iterations:2 delta_A:0.000386896831043 delta_w:1.42187111704e-06
# 224
# 0.03,0.5,91.1
# iterations:1 delta_A:0.581894738878 delta_w:0.0016058230586
# iterations:2 delta_A:0.000209399441371 delta_w:7.58894436101e-07
# 225
# 0.03,0.5,111.1
# iterations:1 delta_A:0.443330295784 delta_w:0.00127154794972
# iterations:2 delta_A:0.000132560979419 delta_w:4.77378342295e-07
# 226
# 0.03,0.6,0.02
# iterations:1 delta_A:81.9429832812 delta_w:0.341064674945
# iterations:2 delta_A:25.5783854315 delta_w:0.0567422680044
# iterations:3 delta_A:8.82084036903 delta_w:0.0163602816763
# iterations:4 delta_A:3.09013642177 delta_w:0.00588426881123
# iterations:5 delta_A:1.13907650548 delta_w:0.00213826757606
# iterations:6 delta_A:0.425063258918 delta_w:0.000797689443114
# 227
# 0.03,0.6,0.04
# iterations:1 delta_A:82.3056066126 delta_w:0.322298251479
# iterations:2 delta_A:21.5317716575 delta_w:0.073743976761
# iterations:3 delta_A:7.72372635097 delta_w:0.0243231822669
# iterations:4 delta_A:2.70691443848 delta_w:0.00833506661263
# iterations:5 delta_A:0.968611205657 delta_w:0.00294109167329
# iterations:6 delta_A:0.350355591287 delta_w:0.00104424355107
# iterations:7 delta_A:0.126040806253 delta_w:0.000368465330382
# 228
# 0.03,0.6,0.06
# iterations:1 delta_A:81.1925799586 delta_w:0.212274350704
# iterations:2 delta_A:14.5827186938 delta_w:0.0356794999539
# iterations:3 delta_A:3.79642421333 delta_w:0.00901304347114
# iterations:4 delta_A:1.18593807897 delta_w:0.00290985347974
# iterations:5 delta_A:0.396457536554 delta_w:0.000984346137198
# 229
# 0.03,0.6,0.08
# iterations:1 delta_A:82.6444520349 delta_w:0.276651393427
# iterations:2 delta_A:12.776547241 delta_w:0.0430557333558
# iterations:3 delta_A:3.09305527034 delta_w:0.0117253783209
# iterations:4 delta_A:0.919409183383 delta_w:0.00356186858299
# iterations:5 delta_A:0.29117081746 delta_w:0.00113517992848
# iterations:6 delta_A:0.0946362754259 delta_w:0.000369931332087
# 230
# 0.03,0.6,0.1
# iterations:1 delta_A:77.1345880996 delta_w:0.258772050292
# iterations:2 delta_A:15.8835809333 delta_w:0.0471163731835
# iterations:3 delta_A:5.03079464051 delta_w:0.0161826965928
# iterations:4 delta_A:1.70252334291 delta_w:0.00567755623401
# iterations:5 delta_A:0.586527599238 delta_w:0.00202184795175
# iterations:6 delta_A:0.203078068255 delta_w:0.000717022579432
# 231
# 0.03,0.6,0.2
# iterations:1 delta_A:72.0267677128 delta_w:0.256875955916
# iterations:2 delta_A:10.7114398813 delta_w:0.0375584606531
# iterations:3 delta_A:2.34853816441 delta_w:0.00845909029877
# iterations:4 delta_A:0.581642750967 delta_w:0.00210988465877
# iterations:5 delta_A:0.152486008552 delta_w:0.00056035388217
# 232
# 0.03,0.6,0.3
# iterations:1 delta_A:70.0943328801 delta_w:0.236060152854
# iterations:2 delta_A:9.03599068034 delta_w:0.0405702404809
# iterations:3 delta_A:1.91315893463 delta_w:0.00893168223658
# iterations:4 delta_A:0.442784853472 delta_w:0.00204850770017
# iterations:5 delta_A:0.10555227497 delta_w:0.000482858230537
# 233
# 0.03,0.6,0.4
# iterations:1 delta_A:63.5676440566 delta_w:0.200162081935
# iterations:2 delta_A:6.90313548222 delta_w:0.0317321262955
# iterations:3 delta_A:1.20596399743 delta_w:0.00572375379106
# iterations:4 delta_A:0.228843049077 delta_w:0.0010779431452
# iterations:5 delta_A:0.0446766658095 delta_w:0.000207592429175
# 234
# 0.03,0.6,0.5
# iterations:1 delta_A:52.070287761 delta_w:0.225871930869
# iterations:2 delta_A:4.08306407506 delta_w:0.0204143589305
# iterations:3 delta_A:0.60329437047 delta_w:0.00280936758915
# iterations:4 delta_A:0.0958451112767 delta_w:0.000434814189184
# 235
# 0.03,0.6,0.6
# iterations:1 delta_A:51.6265207024 delta_w:0.17092774292
# iterations:2 delta_A:3.71227926653 delta_w:0.0170491919448
# iterations:3 delta_A:0.442902591605 delta_w:0.00210474243026
# iterations:4 delta_A:0.0572226776661 delta_w:0.000274091914922
# 236
# 0.03,0.6,0.7
# iterations:1 delta_A:49.1571017841 delta_w:0.152454549926
# iterations:2 delta_A:2.56903436849 delta_w:0.0112221035543
# iterations:3 delta_A:0.239679718989 delta_w:0.00106859166464
# iterations:4 delta_A:0.0252181237649 delta_w:0.000111732669848
# 237
# 0.03,0.6,0.8
# iterations:1 delta_A:51.3557696647 delta_w:0.175748983519
# iterations:2 delta_A:3.71877137606 delta_w:0.0144361614771
# iterations:3 delta_A:0.375836219313 delta_w:0.00143066256525
# iterations:4 delta_A:0.0389859280737 delta_w:0.000146902265444
# 238
# 0.03,0.6,0.9
# iterations:1 delta_A:47.3561525485 delta_w:0.18044248774
# iterations:2 delta_A:2.8683248828 delta_w:0.0127392887768
# iterations:3 delta_A:0.246290933518 delta_w:0.00107825102905
# iterations:4 delta_A:0.0226207263792 delta_w:9.82648939521e-05
# 239
# 0.03,0.6,1.0
# iterations:1 delta_A:43.2417874238 delta_w:0.144545753198
# iterations:2 delta_A:2.20111824649 delta_w:0.00898289152351
# iterations:3 delta_A:0.167258078202 delta_w:0.000693245735865
# 240
# 0.03,0.6,1.1
# iterations:1 delta_A:40.459235642 delta_w:0.158458392988
# iterations:2 delta_A:1.7401340201 delta_w:0.00811108894432
# iterations:3 delta_A:0.104945072093 delta_w:0.000499889199907
# 241
# 0.03,0.6,3.1
# iterations:1 delta_A:18.1617708309 delta_w:0.0692796521807
# iterations:2 delta_A:0.265576393403 delta_w:0.00128124424876
# iterations:3 delta_A:0.00589583355375 delta_w:2.73762961886e-05
# 242
# 0.03,0.6,5.1
# iterations:1 delta_A:12.3256563805 delta_w:0.0435638551621
# iterations:2 delta_A:0.114708495153 delta_w:0.000476498482227
# 243
# 0.03,0.6,7.1
# iterations:1 delta_A:10.5690451877 delta_w:0.0372954695627
# iterations:2 delta_A:0.0990478743368 delta_w:0.000388765387079
# 244
# 0.03,0.6,9.1
# iterations:1 delta_A:5.65349313085 delta_w:0.0178288629484
# iterations:2 delta_A:0.0211607812305 delta_w:9.51595401659e-05
# 245
# 0.03,0.6,11.1
# iterations:1 delta_A:5.3445870827 delta_w:0.0185759901186
# iterations:2 delta_A:0.0210506375868 delta_w:9.2831071447e-05
# 246
# 0.03,0.6,31.1
# iterations:1 delta_A:2.11036878327 delta_w:0.00727454055405
# iterations:2 delta_A:0.00377839449128 delta_w:1.75151371952e-05
# 247
# 0.03,0.6,51.1
# iterations:1 delta_A:1.14402289601 delta_w:0.0040395608585
# iterations:2 delta_A:0.00115052512983 delta_w:4.85471113704e-06
# 248
# 0.03,0.6,71.1
# iterations:1 delta_A:0.811704487158 delta_w:0.0031981459342
# iterations:2 delta_A:0.000641139224778 delta_w:2.99117570328e-06
# 249
# 0.03,0.6,91.1
# iterations:1 delta_A:0.598326065146 delta_w:0.00212698113154
# iterations:2 delta_A:0.000297645997436 delta_w:1.29861122705e-06
# 250
# 0.03,0.6,111.1
# iterations:1 delta_A:0.565708925353 delta_w:0.00208734346484
# iterations:2 delta_A:0.000212006553908 delta_w:9.86639616424e-07
# 251
# 0.03,0.7,0.02
# iterations:1 delta_A:84.9341242251 delta_w:0.284200257381
# iterations:2 delta_A:30.5388931876 delta_w:0.0806826230858
# iterations:3 delta_A:14.9961102578 delta_w:0.0316658117573
# iterations:4 delta_A:7.04285495949 delta_w:0.0130973204158
# iterations:5 delta_A:3.21791916763 delta_w:0.00584969637635
# iterations:6 delta_A:1.50354650657 delta_w:0.00265213297143
# iterations:7 delta_A:0.68372984137 delta_w:0.00119533541526
# iterations:8 delta_A:0.308104025854 delta_w:0.000540970970031
# 252
# 0.03,0.7,0.04
# iterations:1 delta_A:86.0669537272 delta_w:0.376722276663
# iterations:2 delta_A:24.0381020364 delta_w:0.0740976443544
# iterations:3 delta_A:8.33157953221 delta_w:0.0245022694567
# iterations:4 delta_A:2.90586003733 delta_w:0.00844618608149
# iterations:5 delta_A:1.05944132638 delta_w:0.00312191618464
# iterations:6 delta_A:0.399144143008 delta_w:0.00118499919705
# iterations:7 delta_A:0.153894523768 delta_w:0.000462784712616
# 253
# 0.03,0.7,0.06
# iterations:1 delta_A:81.3161064853 delta_w:0.263634767726
# iterations:2 delta_A:18.7863753578 delta_w:0.0448474321908
# iterations:3 delta_A:5.72291131138 delta_w:0.0144194725373
# iterations:4 delta_A:1.99618302701 delta_w:0.00535658942097
# iterations:5 delta_A:0.740009270505 delta_w:0.00202604009413
# iterations:6 delta_A:0.285596950286 delta_w:0.00080979501499
# 254
# 0.03,0.7,0.08
# iterations:1 delta_A:81.2930886404 delta_w:0.368587431923
# iterations:2 delta_A:22.0464993662 delta_w:0.0971439091393
# iterations:3 delta_A:8.2116687058 delta_w:0.0360129123359
# iterations:4 delta_A:3.16274323738 delta_w:0.0139982294546
# iterations:5 delta_A:1.24157797776 delta_w:0.00549008235752
# iterations:6 delta_A:0.492085063514 delta_w:0.00219321094747
# iterations:7 delta_A:0.197310972239 delta_w:0.000881032334003
# 255
# 0.03,0.7,0.1
# iterations:1 delta_A:81.2286166894 delta_w:0.333477688241
# iterations:2 delta_A:23.5105058018 delta_w:0.0866502754403
# iterations:3 delta_A:8.6258748551 delta_w:0.0316202629941
# iterations:4 delta_A:3.29571722738 delta_w:0.0120967153954
# iterations:5 delta_A:1.26386929525 delta_w:0.00460416285185
# iterations:6 delta_A:0.484164921867 delta_w:0.00176638734405
# iterations:7 delta_A:0.185462869512 delta_w:0.000672809411261
# 256
# 0.03,0.7,0.2
# iterations:1 delta_A:75.7585275017 delta_w:0.231372821618
# iterations:2 delta_A:13.1727265694 delta_w:0.0511547042082
# iterations:3 delta_A:3.9939162128 delta_w:0.0163360082656
# iterations:4 delta_A:1.33350794026 delta_w:0.00559498415398
# iterations:5 delta_A:0.457375747747 delta_w:0.00194813850245
# iterations:6 delta_A:0.159190999275 delta_w:0.000684711887546
# 257
# 0.03,0.7,0.3
# iterations:1 delta_A:67.1593685262 delta_w:0.2670737347
# iterations:2 delta_A:10.3311682296 delta_w:0.0484959473986
# iterations:3 delta_A:2.45124562813 delta_w:0.0113397553786
# iterations:4 delta_A:0.628030082564 delta_w:0.00282071974746
# iterations:5 delta_A:0.165281805432 delta_w:0.0007286087822
# 258
# 0.03,0.7,0.4
# iterations:1 delta_A:64.1817715861 delta_w:0.26924380786
# iterations:2 delta_A:10.156762981 delta_w:0.0496280323582
# iterations:3 delta_A:2.49367354807 delta_w:0.0121785297835
# iterations:4 delta_A:0.645222639641 delta_w:0.00316202691593
# iterations:5 delta_A:0.170227763639 delta_w:0.000836158690187
# 259
# 0.03,0.7,0.5
# iterations:1 delta_A:55.5961035754 delta_w:0.177145779154
# iterations:2 delta_A:5.09558341466 delta_w:0.0244376656683
# iterations:3 delta_A:0.918518283084 delta_w:0.00460349750941
# iterations:4 delta_A:0.187697101795 delta_w:0.000935806482696
# 260
# 0.03,0.7,0.6
# iterations:1 delta_A:52.2660595747 delta_w:0.200971272256
# iterations:2 delta_A:4.18876509581 delta_w:0.0217795293488
# iterations:3 delta_A:0.658468093939 delta_w:0.00340504172482
# iterations:4 delta_A:0.117778152451 delta_w:0.000602004171463
# 261
# 0.03,0.7,0.7
# iterations:1 delta_A:51.8217467932 delta_w:0.184964024258
# iterations:2 delta_A:3.6915483191 delta_w:0.01901627115
# iterations:3 delta_A:0.461241026918 delta_w:0.00244720856534
# iterations:4 delta_A:0.0658224864689 delta_w:0.000346792115274
# 262
# 0.03,0.7,0.8
# iterations:1 delta_A:49.2954476689 delta_w:0.209657527478
# iterations:2 delta_A:3.554947381 delta_w:0.0199833670167
# iterations:3 delta_A:0.420214362195 delta_w:0.00240436524724
# iterations:4 delta_A:0.0539430164321 delta_w:0.000306763197307
# 263
# 0.03,0.7,0.9
# iterations:1 delta_A:48.5625456461 delta_w:0.197577521218
# iterations:2 delta_A:3.52086791707 delta_w:0.0176000061481
# iterations:3 delta_A:0.397552229049 delta_w:0.00199306388941
# iterations:4 delta_A:0.0494335570942 delta_w:0.000246189723231
# 264
# 0.03,0.7,1.0
# iterations:1 delta_A:49.4567153336 delta_w:0.219715125719
# iterations:2 delta_A:3.25291476272 delta_w:0.0180785778803
# iterations:3 delta_A:0.297551265096 delta_w:0.00170963109718
# iterations:4 delta_A:0.0291676491194 delta_w:0.000170724537965
# 265
# 0.03,0.7,1.1
# iterations:1 delta_A:46.813237322 delta_w:0.191476977883
# iterations:2 delta_A:3.3402935386 delta_w:0.0161277662961
# iterations:3 delta_A:0.340630875289 delta_w:0.00165654698022
# iterations:4 delta_A:0.0364778163724 delta_w:0.00017875682457
# 266
# 0.03,0.7,3.1
# iterations:1 delta_A:19.888978698 delta_w:0.0880317267765
# iterations:2 delta_A:0.396602472684 delta_w:0.00226407158229
# iterations:3 delta_A:0.0122034180452 delta_w:7.27354443521e-05
# 267
# 0.03,0.7,5.1
# iterations:1 delta_A:14.7670524251 delta_w:0.0564688098203
# iterations:2 delta_A:0.207056703685 delta_w:0.000961648917539
# 268
# 0.03,0.7,7.1
# iterations:1 delta_A:12.0733061968 delta_w:0.0484867116663
# iterations:2 delta_A:0.152553473561 delta_w:0.000754998628979
# 269
# 0.03,0.7,9.1
# iterations:1 delta_A:7.23580388288 delta_w:0.0242689862693
# iterations:2 delta_A:0.0413462292143 delta_w:0.000204870259265
# 270
# 0.03,0.7,11.1
# iterations:1 delta_A:5.8374213759 delta_w:0.027345695549
# iterations:2 delta_A:0.0395999457685 delta_w:0.000207506184792
# 271
# 0.03,0.7,31.1
# iterations:1 delta_A:2.05801207359 delta_w:0.00829806526726
# iterations:2 delta_A:0.00395119329236 delta_w:2.17711213341e-05
# 272
# 0.03,0.7,51.1
# iterations:1 delta_A:1.32290472278 delta_w:0.00526591331258
# iterations:2 delta_A:0.00186868556836 delta_w:8.91273012021e-06
# 273
# 0.03,0.7,71.1
# iterations:1 delta_A:0.928669581236 delta_w:0.00391552868081
# iterations:2 delta_A:0.000860532411311 delta_w:4.45687503062e-06
# 274
# 0.03,0.7,91.1
# iterations:1 delta_A:0.744328934998 delta_w:0.00311081110829
# iterations:2 delta_A:0.000597683755745 delta_w:3.01330483537e-06
# 275
# 0.03,0.7,111.1
# iterations:1 delta_A:0.742185062003 delta_w:0.00287946452729
# iterations:2 delta_A:0.000576009773415 delta_w:2.73703759587e-06
# 276
# 0.03,0.8,0.02
# iterations:1 delta_A:82.1523407245 delta_w:0.291539479618
# iterations:2 delta_A:28.6066393218 delta_w:0.0702240976054
# iterations:3 delta_A:13.7426744383 delta_w:0.0270293030895
# iterations:4 delta_A:6.67082384825 delta_w:0.0127714342449
# iterations:5 delta_A:3.35022216233 delta_w:0.00645172291179
# iterations:6 delta_A:1.71842785187 delta_w:0.00338654979183
# iterations:7 delta_A:0.89270076812 delta_w:0.00178462682934
# iterations:8 delta_A:0.46447311294 delta_w:0.000950316537412
# 277
# 0.03,0.8,0.04
# iterations:1 delta_A:84.4402005805 delta_w:0.386598018721
# iterations:2 delta_A:33.4859638776 delta_w:0.106287787424
# iterations:3 delta_A:15.8050243991 delta_w:0.0447587153026
# iterations:4 delta_A:7.27493689317 delta_w:0.0193093974046
# iterations:5 delta_A:3.30097596279 delta_w:0.00906709802329
# iterations:6 delta_A:1.51057196521 delta_w:0.00432683436996
# iterations:7 delta_A:0.706931044856 delta_w:0.00209563953544
# iterations:8 delta_A:0.336339482102 delta_w:0.00102441898056
# iterations:9 delta_A:0.161994187469 delta_w:0.000505287582355
# 278
# 0.03,0.8,0.06
# iterations:1 delta_A:87.7161662266 delta_w:0.451401321798
# iterations:2 delta_A:37.7036229792 delta_w:0.160222259683
# iterations:3 delta_A:19.8376220696 delta_w:0.0768038594806
# iterations:4 delta_A:10.0175030422 delta_w:0.0361671186182
# iterations:5 delta_A:4.85535653913 delta_w:0.0174408353735
# iterations:6 delta_A:2.34084456415 delta_w:0.00841980866968
# iterations:7 delta_A:1.12497672268 delta_w:0.00408304667882
# iterations:8 delta_A:0.543253531109 delta_w:0.00200014274526
# iterations:9 delta_A:0.263737794862 delta_w:0.000981728131117
# 279
# 0.03,0.8,0.08
# iterations:1 delta_A:79.6574612629 delta_w:0.362949061832
# iterations:2 delta_A:22.1369612499 delta_w:0.0779905219607
# iterations:3 delta_A:7.44645127422 delta_w:0.0252277812618
# iterations:4 delta_A:2.75612877493 delta_w:0.00897848766498
# iterations:5 delta_A:1.08178468245 delta_w:0.00344831122307
# iterations:6 delta_A:0.442789072984 delta_w:0.00139373259824
# iterations:7 delta_A:0.18656473132 delta_w:0.000584318514523
# 280
# 0.03,0.8,0.1
# iterations:1 delta_A:82.56386138 delta_w:0.406412050377
# iterations:2 delta_A:26.3434576046 delta_w:0.106515826025
# iterations:3 delta_A:10.5489713853 delta_w:0.0423354969293
# iterations:4 delta_A:4.56503094619 delta_w:0.0177829656244
# iterations:5 delta_A:2.04205094919 delta_w:0.0079935829029
# iterations:6 delta_A:0.940896774549 delta_w:0.00366891076891
# iterations:7 delta_A:0.440735709269 delta_w:0.00172233806023
# iterations:8 delta_A:0.208299371353 delta_w:0.000818116437504
# 281
# 0.03,0.8,0.2
# iterations:1 delta_A:78.5857271358 delta_w:0.408670864058
# iterations:2 delta_A:15.8088416705 delta_w:0.0871916682601
# iterations:3 delta_A:4.73339488519 delta_w:0.0284925260556
# iterations:4 delta_A:1.56212831253 delta_w:0.00969285086428
# iterations:5 delta_A:0.538285499559 delta_w:0.00343416510359
# iterations:6 delta_A:0.194646339159 delta_w:0.00125778178648
# iterations:7 delta_A:0.0736658732742 delta_w:0.000475466838145
# 282
# 0.03,0.8,0.3
# iterations:1 delta_A:72.4775508493 delta_w:0.396793484909
# iterations:2 delta_A:13.0143135634 delta_w:0.083189307754
# iterations:3 delta_A:3.53181435843 delta_w:0.0243631544979
# iterations:4 delta_A:1.05530987453 delta_w:0.00738519513064
# iterations:5 delta_A:0.328989731541 delta_w:0.00231563494944
# iterations:6 delta_A:0.105200934557 delta_w:0.000737416478477
# 283
# 0.03,0.8,0.4
# iterations:1 delta_A:64.6282595916 delta_w:0.267803986326
# iterations:2 delta_A:9.37349861096 delta_w:0.0509617312136
# iterations:3 delta_A:2.5240827333 delta_w:0.014136519503
# iterations:4 delta_A:0.760030255185 delta_w:0.00427640792992
# ...
# iterations:4 delta_A:108.323065486 delta_w:8.38385393929
# iterations:5 delta_A:108.933465838 delta_w:8.47434990306
# iterations:6 delta_A:109.279691092 delta_w:8.51958124498
# iterations:7 delta_A:109.402030921 delta_w:8.54927126951
# iterations:8 delta_A:109.743969284 delta_w:8.54779110802
# iterations:9 delta_A:109.983898552 delta_w:8.54497873872
# iterations:10 delta_A:110.096092194 delta_w:8.55890055227
# iterations:11 delta_A:110.121449419 delta_w:8.54771701421
# iterations:12 delta_A:110.286847057 delta_w:8.57472145565
# iterations:13 delta_A:110.371381894 delta_w:8.58239191492
# iterations:14 delta_A:110.507502061 delta_w:8.61494657152
# iterations:15 delta_A:110.625185616 delta_w:8.62584550961
# iterations:16 delta_A:110.717139568 delta_w:8.64875701104
# iterations:17 delta_A:110.799642243 delta_w:8.67032202731
# iterations:18 delta_A:110.909480798 delta_w:8.68830619815
# iterations:19 delta_A:110.945094169 delta_w:8.70880440097
# iterations:20 delta_A:110.974448801 delta_w:8.71859129304
# 466
# 0.03,9.1,3.1
# iterations:1 delta_A:95.5296432705 delta_w:5.29655183907
# iterations:2 delta_A:96.2931358115 delta_w:6.51824738319
# iterations:3 delta_A:102.800006437 delta_w:7.50639635846
# iterations:4 delta_A:107.085860844 delta_w:8.29274414384
# iterations:5 delta_A:107.975593107 delta_w:8.59420973265
# iterations:6 delta_A:109.07735978 delta_w:8.82873493611
# iterations:7 delta_A:109.403809531 delta_w:8.92645927874
# iterations:8 delta_A:109.720930998 delta_w:8.98974898813
# iterations:9 delta_A:109.740555529 delta_w:9.02120807291
# iterations:10 delta_A:109.793061325 delta_w:9.0434110628
# iterations:11 delta_A:109.797520258 delta_w:9.05985297174
# iterations:12 delta_A:109.812010561 delta_w:9.07375290919
# iterations:13 delta_A:109.821473428 delta_w:9.08527782841
# iterations:14 delta_A:109.829979664 delta_w:9.09595123114
# iterations:15 delta_A:109.846314155 delta_w:9.10477125073
# iterations:16 delta_A:109.852950972 delta_w:9.11345869072
# iterations:17 delta_A:109.86927739 delta_w:9.12107233587
# iterations:18 delta_A:109.872402647 delta_w:9.12827857222
# iterations:19 delta_A:109.880012787 delta_w:9.1344123527
# iterations:20 delta_A:109.880878927 delta_w:9.14103945424
# 467
# 0.03,9.1,5.1
# iterations:1 delta_A:92.9011887957 delta_w:5.81868079858
# iterations:2 delta_A:91.5579805933 delta_w:6.63207879374
# iterations:3 delta_A:97.2082638266 delta_w:7.15013615351
# iterations:4 delta_A:100.196836639 delta_w:7.46028404007
# iterations:5 delta_A:103.723377487 delta_w:7.85940000942
# iterations:6 delta_A:105.247478236 delta_w:8.13333546253
# iterations:7 delta_A:106.356991448 delta_w:8.37300209698
# iterations:8 delta_A:106.708023732 delta_w:8.50159140162
# iterations:9 delta_A:107.125202892 delta_w:8.6550873381
# iterations:10 delta_A:107.213246653 delta_w:8.72263136422
# iterations:11 delta_A:107.423282483 delta_w:8.80041066807
# iterations:12 delta_A:107.470494031 delta_w:8.83897383284
# iterations:13 delta_A:107.566700365 delta_w:8.88011302036
# iterations:14 delta_A:107.596541127 delta_w:8.90429553069
# iterations:15 delta_A:107.642433189 delta_w:8.92926598566
# iterations:16 delta_A:107.664120876 delta_w:8.94512882067
# iterations:17 delta_A:107.695143019 delta_w:8.96089913852
# iterations:18 delta_A:107.706928007 delta_w:8.97120406324
# iterations:19 delta_A:107.719741587 delta_w:8.98142378888
# iterations:20 delta_A:107.728446588 delta_w:8.9886706898
# 468
# 0.03,9.1,7.1
# iterations:1 delta_A:86.2189005715 delta_w:5.15370181853
# iterations:2 delta_A:81.2081377329 delta_w:5.69537107016
# iterations:3 delta_A:86.5914658736 delta_w:6.24597487439
# iterations:4 delta_A:89.8623790358 delta_w:6.72890235158
# iterations:5 delta_A:91.664265942 delta_w:7.14084023838
# iterations:6 delta_A:94.2512489156 delta_w:7.64507252191
# iterations:7 delta_A:97.0461843837 delta_w:8.04400687075
# iterations:8 delta_A:99.7211976184 delta_w:8.26695874832
# iterations:9 delta_A:100.864712343 delta_w:8.29296285145
# iterations:10 delta_A:101.505081915 delta_w:8.29873933489
# iterations:11 delta_A:101.831860872 delta_w:8.29244457174
# iterations:12 delta_A:102.251930962 delta_w:8.31068579282
# iterations:13 delta_A:102.493336461 delta_w:8.30961129439
# iterations:14 delta_A:102.828075096 delta_w:8.32588247818
# iterations:15 delta_A:103.174498104 delta_w:8.334935837
# iterations:16 delta_A:103.411657199 delta_w:8.34271109461
# iterations:17 delta_A:103.594118162 delta_w:8.34129940447
# iterations:18 delta_A:103.666304838 delta_w:8.33957109862
# iterations:19 delta_A:103.706285205 delta_w:8.33602550996
# iterations:20 delta_A:103.714949307 delta_w:8.33314440793
# 469
# 0.03,9.1,9.1
# iterations:1 delta_A:79.2807175195 delta_w:4.82606460507
# iterations:2 delta_A:75.9477762282 delta_w:5.60370068649
# iterations:3 delta_A:85.4696835613 delta_w:6.44415094475
# iterations:4 delta_A:91.9219389201 delta_w:7.09642039741
# iterations:5 delta_A:94.5012172787 delta_w:7.43986612694
# iterations:6 delta_A:96.2911725642 delta_w:7.74141843896
# iterations:7 delta_A:97.3899752524 delta_w:7.94839363168
# iterations:8 delta_A:98.568744222 delta_w:8.14988486737
# iterations:9 delta_A:99.4501413643 delta_w:8.29873736363
# iterations:10 delta_A:100.343444504 delta_w:8.42015862543
# iterations:11 delta_A:100.869206821 delta_w:8.49372057725
# iterations:12 delta_A:101.230291727 delta_w:8.53313228729
# iterations:13 delta_A:101.420847943 delta_w:8.55624739608
# iterations:14 delta_A:101.513310956 delta_w:8.56743714675
# iterations:15 delta_A:101.562612032 delta_w:8.57508185568
# iterations:16 delta_A:101.584295018 delta_w:8.57857100178
# iterations:17 delta_A:101.596061451 delta_w:8.58135619172
# iterations:18 delta_A:101.601248069 delta_w:8.58274495866
# iterations:19 delta_A:101.604078344 delta_w:8.58395971217
# iterations:20 delta_A:101.605485476 delta_w:8.58470953834
# 470
# 0.03,9.1,11.1
# iterations:1 delta_A:69.9719067224 delta_w:3.68229583377
# iterations:2 delta_A:60.5489565354 delta_w:4.09728112767
# iterations:3 delta_A:68.1862132985 delta_w:4.79908105344
# iterations:4 delta_A:77.2288825115 delta_w:5.47496603164
# iterations:5 delta_A:83.013370952 delta_w:5.89917941876
# iterations:6 delta_A:86.02424198 delta_w:6.13483309401
# iterations:7 delta_A:87.2714959685 delta_w:6.27187119081
# iterations:8 delta_A:88.6273410174 delta_w:6.46662404158
# iterations:9 delta_A:90.2450528731 delta_w:6.73373462157
# iterations:10 delta_A:92.3157771197 delta_w:7.09526421572
# iterations:11 delta_A:94.0375517337 delta_w:7.41229128496
# iterations:12 delta_A:95.3881652707 delta_w:7.68461006306
# iterations:13 delta_A:96.1081164926 delta_w:7.85006153676
# iterations:14 delta_A:96.6052434147 delta_w:7.97244886117
# iterations:15 delta_A:96.8473662178 delta_w:8.04001985167
# iterations:16 delta_A:97.0201045213 delta_w:8.09187668453
# iterations:17 delta_A:97.1106709169 delta_w:8.12234072528
# iterations:18 delta_A:97.1774909779 delta_w:8.14716215271
# iterations:19 delta_A:97.2150047593 delta_w:8.16263656628
# iterations:20 delta_A:97.2466117847 delta_w:8.17594032318
# 471
# 0.03,9.1,31.1
# iterations:1 delta_A:35.474340804 delta_w:2.08982031436
# iterations:2 delta_A:12.6258919815 delta_w:0.905890492076
# iterations:3 delta_A:5.90635836731 delta_w:0.423950945573
# iterations:4 delta_A:3.06808135275 delta_w:0.21364688205
# iterations:5 delta_A:1.71425345307 delta_w:0.115998583107
# iterations:6 delta_A:1.01062836243 delta_w:0.0670845681982
# iterations:7 delta_A:0.61866236715 delta_w:0.0406397654976
# iterations:8 delta_A:0.388370126817 delta_w:0.0253961361095
# iterations:9 delta_A:0.247830159406 delta_w:0.0161872271945
# iterations:10 delta_A:0.15983158556 delta_w:0.0104461098449
# iterations:11 delta_A:0.103792328588 delta_w:0.00679378728191
# iterations:12 delta_A:0.0677093681668 delta_w:0.00444031210363
# iterations:13 delta_A:0.0443069839682 delta_w:0.00291137949976
# iterations:14 delta_A:0.0290553122718 delta_w:0.00191289905656
# iterations:15 delta_A:0.0190827959248 delta_w:0.00125860853288
# iterations:16 delta_A:0.012547122271 delta_w:0.000828894553316
# 472
# 0.03,9.1,51.1
# iterations:1 delta_A:19.4637263949 delta_w:1.19105301969
# iterations:2 delta_A:4.28569317198 delta_w:0.351662032798
# iterations:3 delta_A:1.36853999198 delta_w:0.116117432038
# iterations:4 delta_A:0.487496069447 delta_w:0.0404483304016
# iterations:5 delta_A:0.182786059637 delta_w:0.0146303736305
# iterations:6 delta_A:0.0704046283135 delta_w:0.00543648698658
# iterations:7 delta_A:0.0275261428047 delta_w:0.00205977379977
# iterations:8 delta_A:0.0108573583295 delta_w:0.000791624979045
# 473
# 0.03,9.1,71.1
# iterations:1 delta_A:16.7620213349 delta_w:1.07913571203
# iterations:2 delta_A:3.54333958269 delta_w:0.262237948797
# iterations:3 delta_A:0.951535687792 delta_w:0.0705681394902
# iterations:4 delta_A:0.267312643512 delta_w:0.0195065842601
# iterations:5 delta_A:0.0762111636263 delta_w:0.00546258109091
# iterations:6 delta_A:0.021862774643 delta_w:0.0015425317245
# iterations:7 delta_A:0.00629059483817 delta_w:0.000438156068428
# 474
# 0.03,9.1,91.1
# iterations:1 delta_A:14.1458776277 delta_w:0.756504270864
# iterations:2 delta_A:2.23685936424 delta_w:0.138958803659
# iterations:3 delta_A:0.450030071111 delta_w:0.0282600112262
# iterations:4 delta_A:0.0961961913843 delta_w:0.00608668312961
# iterations:5 delta_A:0.0210676371491 delta_w:0.00134551612474
# iterations:6 delta_A:0.00466391058102 delta_w:0.000300550821015
# 475
# 0.03,9.1,111.1
# iterations:1 delta_A:8.76361301361 delta_w:0.438453575415
# iterations:2 delta_A:1.0665442055 delta_w:0.0617292930583
# iterations:3 delta_A:0.173336046036 delta_w:0.00998932707514
# iterations:4 delta_A:0.0296437939742 delta_w:0.00170265155963
# iterations:5 delta_A:0.00516754574268 delta_w:0.000297654985565
# 476
# 0.03,11.1,0.02
# iterations:1 delta_A:102.08797349 delta_w:7.71095380324
# iterations:2 delta_A:104.788989469 delta_w:9.94660516806
# iterations:3 delta_A:109.428734443 delta_w:10.4793506601
# iterations:4 delta_A:111.113618226 delta_w:10.5462001955
# iterations:5 delta_A:111.3616856 delta_w:10.4564802455
# iterations:6 delta_A:111.426529252 delta_w:10.3288214108
# iterations:7 delta_A:111.478148169 delta_w:10.2638521236
# iterations:8 delta_A:111.512979988 delta_w:10.2501630196
# iterations:9 delta_A:111.558239795 delta_w:10.2557740905
# iterations:10 delta_A:111.554970513 delta_w:10.2820558667
# iterations:11 delta_A:111.6637299 delta_w:10.3308508119
# iterations:12 delta_A:111.649231269 delta_w:10.3555619258
# iterations:13 delta_A:111.591039927 delta_w:10.3907282969
# iterations:14 delta_A:111.733139299 delta_w:10.4299163363
# iterations:15 delta_A:111.70116289 delta_w:10.4377885997
# iterations:16 delta_A:111.740328767 delta_w:10.4503760984
# iterations:17 delta_A:111.737582611 delta_w:10.4522478292
# iterations:18 delta_A:111.718396933 delta_w:10.4523597378
# iterations:19 delta_A:111.707635517 delta_w:10.4530881303
# iterations:20 delta_A:111.691079931 delta_w:10.4481545179
# 477
# 0.03,11.1,0.04
# iterations:1 delta_A:103.582322058 delta_w:7.12230914849
# iterations:2 delta_A:107.372374441 delta_w:7.98915676081
# iterations:3 delta_A:110.249724123 delta_w:8.21589603688
# iterations:4 delta_A:110.561209533 delta_w:8.22130491999
# iterations:5 delta_A:110.87497397 delta_w:8.27385784626
# iterations:6 delta_A:110.907159087 delta_w:8.32524921693
# iterations:7 delta_A:111.002312031 delta_w:8.37700670121
# iterations:8 delta_A:110.912966617 delta_w:8.37725783919
# iterations:9 delta_A:110.976073059 delta_w:8.39762251066
# iterations:10 delta_A:110.900817015 delta_w:8.42229752676
# iterations:11 delta_A:110.770524856 delta_w:8.42555270933
# iterations:12 delta_A:110.766348835 delta_w:8.43082573553
# iterations:13 delta_A:110.671467144 delta_w:8.44517102996
# iterations:14 delta_A:110.705885517 delta_w:8.46022357437
# iterations:15 delta_A:110.826028377 delta_w:8.49551145459
# iterations:16 delta_A:110.743421182 delta_w:8.50829264667
# iterations:17 delta_A:110.767223899 delta_w:8.51270567104
# iterations:18 delta_A:110.657665668 delta_w:8.51026764096
# iterations:19 delta_A:110.630810538 delta_w:8.52303486453
# iterations:20 delta_A:110.588654943 delta_w:8.52579583472
# 478
# 0.03,11.1,0.06
# iterations:1 delta_A:103.128993807 delta_w:6.45152206025
# iterations:2 delta_A:102.595405124 delta_w:7.08917623451
# iterations:3 delta_A:108.146101922 delta_w:7.42904319162
# iterations:4 delta_A:108.636166832 delta_w:7.56340356955
# iterations:5 delta_A:109.455419693 delta_w:7.81979670489
# iterations:6 delta_A:109.194195076 delta_w:8.18195284291
# iterations:7 delta_A:109.403324212 delta_w:8.46659366505
# iterations:8 delta_A:110.032472241 delta_w:8.75803679148
# iterations:9 delta_A:110.409829388 delta_w:9.13253039642
# iterations:10 delta_A:110.263096953 delta_w:9.35466584689
# iterations:11 delta_A:110.905154023 delta_w:9.65315161567
# iterations:12 delta_A:110.803384154 delta_w:9.86772879596
# iterations:13 delta_A:110.939205662 delta_w:10.096188191
# iterations:14 delta_A:111.348028812 delta_w:10.2454107457
# iterations:15 delta_A:111.466093134 delta_w:10.388394721
# iterations:16 delta_A:111.696968848 delta_w:10.4651990644
# iterations:17 delta_A:111.941650352 delta_w:10.5400908528
# iterations:18 delta_A:112.178565673 delta_w:10.6039711836
# iterations:19 delta_A:112.455420735 delta_w:10.6444334997
# iterations:20 delta_A:112.447755146 delta_w:10.6734504331
# 479
# 0.03,11.1,0.08
# iterations:1 delta_A:102.277348121 delta_w:6.70234687378
# iterations:2 delta_A:106.207476414 delta_w:8.44362103089
# iterations:3 delta_A:110.302399478 delta_w:9.17102902
# iterations:4 delta_A:111.091605343 delta_w:9.48703624161
# iterations:5 delta_A:111.23508963 delta_w:9.61281692992
# iterations:6 delta_A:111.428299923 delta_w:9.7154526129
# iterations:7 delta_A:111.034988132 delta_w:9.79608168687
# iterations:8 delta_A:111.261123726 delta_w:9.87408605944
# iterations:9 delta_A:111.058460365 delta_w:9.94582775189
# iterations:10 delta_A:111.321257171 delta_w:9.97596808209
# iterations:11 delta_A:111.354169537 delta_w:10.0445736861
# iterations:12 delta_A:111.398538148 delta_w:10.127854079
# iterations:13 delta_A:111.454946355 delta_w:10.1853069289
# iterations:14 delta_A:111.548343205 delta_w:10.2347291919
# iterations:15 delta_A:111.606392348 delta_w:10.2567165406
# iterations:16 delta_A:111.614422311 delta_w:10.2729597723
# iterations:17 delta_A:111.589533648 delta_w:10.2790068981
# iterations:18 delta_A:111.594568566 delta_w:10.2833507948
# iterations:19 delta_A:111.594436012 delta_w:10.283398455
# iterations:20 delta_A:111.594505261 delta_w:10.2834004361
# 480
# 0.03,11.1,0.1
# iterations:1 delta_A:102.985255749 delta_w:7.2155623173
# iterations:2 delta_A:107.256592032 delta_w:8.51683239197
# iterations:3 delta_A:109.923328817 delta_w:9.09441263366
# iterations:4 delta_A:109.602426391 delta_w:9.36326065883
# iterations:5 delta_A:110.149710949 delta_w:9.60404399128
# iterations:6 delta_A:109.83873375 delta_w:9.82808555234
# iterations:7 delta_A:110.656202315 delta_w:10.1036133585
# iterations:8 delta_A:110.325830873 delta_w:10.3371886292
# iterations:9 delta_A:110.916083948 delta_w:10.692256469
# iterations:10 delta_A:110.653398344 delta_w:10.9086487077
# iterations:11 delta_A:111.892502702 delta_w:11.1820110197
# iterations:12 delta_A:112.207279999 delta_w:11.357996802
# iterations:13 delta_A:112.84531002 delta_w:11.547743486
# iterations:14 delta_A:113.044839821 delta_w:11.6240531961
# iterations:15 delta_A:113.136008421 delta_w:11.6371813385
# iterations:16 delta_A:113.176919306 delta_w:11.645707402
# iterations:17 delta_A:113.179532353 delta_w:11.6267248471
# iterations:18 delta_A:113.114791946 delta_w:11.6050762375
# iterations:19 delta_A:113.112501288 delta_w:11.6027919625
# iterations:20 delta_A:113.102026972 delta_w:11.6001851254
# 481
# 0.03,11.1,0.2
# iterations:1 delta_A:102.931880704 delta_w:6.87491149639
# iterations:2 delta_A:103.698443885 delta_w:8.52495773811
# iterations:3 delta_A:107.871760547 delta_w:9.55719043259
# iterations:4 delta_A:108.789606074 delta_w:9.81832561893
# iterations:5 delta_A:109.374862954 delta_w:9.82905354026
# iterations:6 delta_A:109.712643045 delta_w:9.77228411649
# iterations:7 delta_A:110.678330492 delta_w:10.032192361
# iterations:8 delta_A:111.089986047 delta_w:10.2838487279
# iterations:9 delta_A:111.714357832 delta_w:10.4216985598
# iterations:10 delta_A:111.735725542 delta_w:10.4514658543
# iterations:11 delta_A:111.819466816 delta_w:10.4729621907
# iterations:12 delta_A:111.567752421 delta_w:10.4698079104

# %%
import operator
sorted_Performance = sorted(Performace.items(), key=operator.itemgetter(1))

# %%
sorted_Performance[-10:-1]
# Out:
# [('0.01,0.5,0.5', 0.9608011444921316),
#  ('0.01,0.7,0.9', 0.9608011444921316),
#  ('0.01,7.1,91.1', 0.9608011444921316),
#  ('0.01,11.1,91.1', 0.9610538373424972),
#  ('0.01,1.1,0.9', 0.9610538373424972),
#  ('0.01,3.1,7.1', 0.9610538373424972),
#  ('0.01,0.3,0.1', 0.9610761305094448),
#  ('0.01,0.3,0.08', 0.9610761305094448),
#  ('0.01,0.5,0.02', 0.9610761305094448)]
